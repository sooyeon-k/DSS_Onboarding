# %% [markdown]
# # Homework 2: Data Cleaning, EDA and Visualizations #

# %%
#import any libraries that you may need here
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# ### We would like our new consultants and mentors to not just be technically skilled but also ethical leaders in their fields. Therefore, let us go over some basic data ethics knowledge. ###

# %% [markdown]
# ## Section 1: Data Ethics
#
# ### What are the different types of biases we mentioned during lecture? Pick one that you observe in yourself and describe how it may influence your decision-making.

# %% [markdown]
# The different types of biases mentioned during lecture are: selection, unconcious, algorithmic, and confounding bias. One bias that I would observe in myself is unconcious bias, more specifically confirmation bias and this can influence my decision making because it changes the reality from where I draw evidence.

# %% [markdown]
# ### How do you think you could overcome your biases?

# %% [markdown]
# I can overcome confirmation biases by making sure that the sample from which I am drawing my evidence from is represenative and keeping an open mind to conflicting findings.

# %% [markdown]
# ### What is one example of how unethical data analysis impacted a group of people? Avoid repeating the lecture example.

# %% [markdown]
# An unethical data case study would be the Havasupai genetic case study.

# %% [markdown]
# ## Section 2: Data Cleaning

# %% [markdown]
# ### Pick out a dataset that you are interested in working with on [Kaggle](https://www.kaggle.com/datasets)! You should continue working with it in future homeworks so that you have a comprehensive data science project by the end of the semester so pick a good one.
# ### Download it and add it to the same folder that you are working in so that you are able to load it easily. You can refer to the [slides](https://docs.google.com/presentation/d/1UPj0F_I0CYoiUrbuSR9sYq50FEh8-RDG4usnTFaUBJI/edit#slide=id.g1c0cc4ea8d8_0_1369) that we used for onboarding for any help. ###

# %%
# load your dataset here, df is short for DataFrame. 
# E.g.You can use pd.read_csv() for csv files. 
df = pd.read_csv("./Infectious Disease 2001-2014.csv")

# %% [markdown]
# ####  Example

# %% [markdown]
# ### Now let's do some data cleaning! Here are a list of questions that you should think through and answer while looking at your data. If your data is from kaggle, it might already be really clean, but practise answering these questions.
#
# ### *At this point, just answer these questions and examine your data but don't attempt to clean it yet* ###
#
# - Does your data contain unrealistic or incorrect values?
#     - Dates in the future
#     - Locations that don’t exist
#     - Negative counts
# - Does your data violate obvious dependencies?
#     - Age and birthday not matching
# - Is the data coherent and consistent?
#     - Misspellings and inconsistent labels
#     - Was the data entered by hand?
# - Are there signs of data falsification?
#     - Repeated names, fake looking email addresses, uncommon names or fields
# - Do we need to convert any of the variable types in order to prepare for modelling?
#     - Qualitative variables that you might want to convert to numbers
# - Any other interesting observations?

# %%
df
# Out:
#             Disease      County  Year     Sex  Count  Population   Rate  \
# 0         Amebiasis  California  2001   Total    571    34514777  1.654
# 1         Amebiasis  California  2001  Female    176    17340743  1.015
# 2         Amebiasis  California  2001    Male    365    17174034  2.125
# 3         Amebiasis  California  2002   Total    442    34940334  1.265
# 4         Amebiasis  California  2002  Female    145    17555714  0.826
# ...             ...         ...   ...     ...    ...         ...    ...
# 141772  Yersiniosis        Yuba  2013  Female      0       36296  0.000
# 141773  Yersiniosis        Yuba  2013    Male      0       36698  0.000
# 141774  Yersiniosis        Yuba  2014   Total      0       73425  0.000
# 141775  Yersiniosis        Yuba  2014  Female      0       36503  0.000
# 141776  Yersiniosis        Yuba  2014    Male      0       36922  0.000
#
#         CI.lower  CI.upper Unstable
# 0          1.521     1.796
# 1          0.871     1.176
# 2          1.913     2.355
# 3          1.150     1.389
# 4          0.697     0.972
# ...          ...       ...      ...
# 141772     0.000    10.163        -
# 141773     0.000    10.051        -
# 141774     0.000     5.024        -
# 141775     0.000    10.105        -
# 141776     0.000     9.991        -
#
# [141777 rows x 10 columns]

# %% [markdown]
# Write your answers to each of the questions here
#
# Q1: Does your data contain unrealistic or incorrect values?
# No my data does not contain unrealistic or incorrect values.
#
# Q2: Does your data violate obvious dependencies?
# No my data does not violate obvious dependecies.
#
# Q3: Is the data coherent and consistent?
# Yes the data is coherent and consistent.
#
# Q4: Are there signs of data falsification?
# No the data and the data types are consistent, but I'm not sure what the 'unstable' column is for because the data seems to be missing.
#
# Q5: Do we need to convert any of the variable types in order to prepare for modelling?
# No.
#
# Q6: Any other interesting observations?
# No.

# %%
# Any exploratory code here
# You can refer to the pandas section of the slides to do this
df.describe()
# Out:
#                 Year          Count    Population           Rate  \
# count  141777.000000  141777.000000  1.417770e+05  141777.000000
# mean     2007.857678      81.368438  8.299702e+05       6.984715
# std         4.052999    1954.637660  3.452198e+06      44.861027
# min      2001.000000       0.000000  5.330000e+02       0.000000
# 25%      2004.000000       0.000000  2.871500e+04       0.000000
# 50%      2008.000000       0.000000  1.239460e+05       0.000000
# 75%      2011.000000       1.000000  4.119620e+05       0.203000
# max      2014.000000  174557.000000  3.850149e+07    1020.550000
#
#             CI.lower       CI.upper
# count  141777.000000  141777.000000
# mean        5.726249      28.912777
# std        41.479404      87.209601
# min         0.000000       0.010000
# 25%         0.000000       1.495000
# 50%         0.000000       5.233000
# 75%         0.010000      17.814000
# max       992.007000    1632.966000

# %% [markdown]
# ### More factors to consider
#
# Here is a list of a few more questions to consider while data cleaning! Answer them to get a deeper understanding of your data.
#
# - Do any of the keys in each table reference each other?
#     - Primary keys are the column or set of columns in a table that determine the values of the remaining columns
#     - Foreign keys are the column or sets of columns that reference primary keys in other tables
#     - Can we merge them tables?
# - What does each field specify?
#     - What is the variable type?
#     - Qualitative(Ordinal and Nominal), Quantitative (Continuous and discrete)
#     - String, integer, float, list, array etc.
# - Granularity? What does each record represent? Are there aggregations?
# - Where was this data collected from? What types of questions were asked to gather this data? How representative is it? When was it collected?
# - Truncated data
#     - Check the platform that you are working on, does it limit your data size?
# - Time zone inconsistencies
#     - Convert to common timezone
# - Duplicated records or fields -> eliminate carefully
# - Spelling errors
# - Units not specified or inconsistent
# - Missing Data
# - Redundant data
# - Simplify
#     - Take one column
#     - Combine multiple columns  into one
# - Aggregation
#     - groupby

# %% [markdown]
# Do any of the keys in each table reference each other?
# No.
#
# What does each field specify?
# Each field specifies information regarding the disease, the  who was infected, location, and time.
#
# Granularity? What does each record represent? Are there aggregations?
# Each row represents the total number of individuals regardless, total number of males, and total number of femals who were infected by a disease and includes demographic information as well as more information about the disease, time, and location.
#
# Where was this data collected from? What types of questions were asked to gather this data? How representative is it? When was it collected?
# According to the description on Kaggle, the data source is listed as "World Data"

# %% [markdown]
# ## Addressing Missing Data/ Default Values

# %% [markdown]
# ### As you cleaned your data, you may have observed missing data/ default values. Decide what to do with these values and explain your decision-making process.
#
# Here are some methods to deal with missing values:
# - Drop records with missing values
#     - Check for biases induced by missing values - there may be trends in why something is missing
#     - This requires domain knowledge to check for induced bias
# - Imputation: Inferring missing values
#     - Replace with average value (closest related subgroup mean)
#     - Replace with a random value from the closest subgroup(Hot deck imputation)
# - Numerical:
#     - mean, mode, median
# - Categorical
#     - Mode, new category
# - Directly model missing values during future analysis

# %%
df
# Out:
#             Disease      County  Year     Sex  Count  Population   Rate  \
# 0         Amebiasis  California  2001   Total    571    34514777  1.654
# 1         Amebiasis  California  2001  Female    176    17340743  1.015
# 2         Amebiasis  California  2001    Male    365    17174034  2.125
# 3         Amebiasis  California  2002   Total    442    34940334  1.265
# 4         Amebiasis  California  2002  Female    145    17555714  0.826
# ...             ...         ...   ...     ...    ...         ...    ...
# 141772  Yersiniosis        Yuba  2013  Female      0       36296  0.000
# 141773  Yersiniosis        Yuba  2013    Male      0       36698  0.000
# 141774  Yersiniosis        Yuba  2014   Total      0       73425  0.000
# 141775  Yersiniosis        Yuba  2014  Female      0       36503  0.000
# 141776  Yersiniosis        Yuba  2014    Male      0       36922  0.000
#
#         CI.lower  CI.upper Unstable
# 0          1.521     1.796
# 1          0.871     1.176
# 2          1.913     2.355
# 3          1.150     1.389
# 4          0.697     0.972
# ...          ...       ...      ...
# 141772     0.000    10.163        -
# 141773     0.000    10.051        -
# 141774     0.000     5.024        -
# 141775     0.000    10.105        -
# 141776     0.000     9.991        -
#
# [141777 rows x 10 columns]

# %%
#Any preliminary cleaning necessary to start dealing with missing values
df.drop(columns = ["Unstable"])
# Out:
#             Disease      County  Year     Sex  Count  Population   Rate  \
# 0         Amebiasis  California  2001   Total    571    34514777  1.654
# 1         Amebiasis  California  2001  Female    176    17340743  1.015
# 2         Amebiasis  California  2001    Male    365    17174034  2.125
# 3         Amebiasis  California  2002   Total    442    34940334  1.265
# 4         Amebiasis  California  2002  Female    145    17555714  0.826
# ...             ...         ...   ...     ...    ...         ...    ...
# 141772  Yersiniosis        Yuba  2013  Female      0       36296  0.000
# 141773  Yersiniosis        Yuba  2013    Male      0       36698  0.000
# 141774  Yersiniosis        Yuba  2014   Total      0       73425  0.000
# 141775  Yersiniosis        Yuba  2014  Female      0       36503  0.000
# 141776  Yersiniosis        Yuba  2014    Male      0       36922  0.000
#
#         CI.lower  CI.upper
# 0          1.521     1.796
# 1          0.871     1.176
# 2          1.913     2.355
# 3          1.150     1.389
# 4          0.697     0.972
# ...          ...       ...
# 141772     0.000    10.163
# 141773     0.000    10.051
# 141774     0.000     5.024
# 141775     0.000    10.105
# 141776     0.000     9.991
#
# [141777 rows x 9 columns]

# %% [markdown]
# Explain what types of missing values you found and the decisions you made in addressing them:
#
# There are no missing values.

# %% [markdown]
# ## Handling outliers

# %% [markdown]
# ### Now let's handle any outliers. Same process as before!
#
# Here are some methods to deal with handling outliers:
# - Drop records with outliers
#     - Check for biases induced by missing values - there may be trends in why something is missing
#     - This requires domain knowledge to check for induced bias
# - Replace, as with Inferring missing values
#     - Typically with min or max
# - Binning
#     - E.g. greater than 5

# %%
df.columns
# Out:
# Index(['Disease', 'County', 'Year', 'Sex', 'Count', 'Population', 'Rate',
#        'CI.lower', 'CI.upper', 'Unstable'],
#       dtype='object')

# %%
# Code addressing outliers here

#columns = ['Count', 'Population', 'Rate', 'CI.lower', 'CI.upper']

'''
for col in columns: 
    Q1 = df[col].quantile(0.25)
 
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    upper_count = Q3 + 1.5 * IQR

    lower_count = Q1 - 1.5 * IQR

    df = df[(df[col] >= lower_count) & (df[col] <= upper_count)]
'''
# Out:
# '\nfor col in columns: \n    Q1 = df[col].quantile(0.25)\n \n    Q3 = df[col].quantile(0.75)\n\n    IQR = Q3 - Q1\n\n    upper_count = Q3 + 1.5 * IQR\n\n    lower_count = Q1 - 1.5 * IQR\n\n    df = df[(df[col] >= lower_count) & (df[col] <= upper_count)]\n'

# %% [markdown]
# Explain what types of outliers you found and the decisions you made in addressing them
#
# I tried to use the IQR method to find the upper and lower cutoffs for the outliers, but did not work as I had originally planned for it to.

# %% [markdown]
# ## Let's clean!

# %% [markdown]
# ### Now that we have a much deeper understanding of our data and have dealt with a few preliminary issues, clean up the data so that it is useful and accurate!

# %%
### Your code here

# %% [markdown]
# ## Section 3: EDA

# %% [markdown]
# ### Study the data and observe any potential trends/ consider models that you might be able to implement. Study the relationships between the different columns and see if you can find any insights. List at least 2 potential project ideas.

# %%
# Exploratory code here

#e.g. df.corr() gives you the correlation coefficients between columns

df.corr()

# potential project ideas: 
# 1: finding infection rates between different areas over time 
# 2: finding infection rates between gender over time
# Out:
#                 Year     Count  Population      Rate  CI.lower  CI.upper
# Year        1.000000  0.002295    0.007662  0.007583  0.007635  0.009070
# Count       0.002295  1.000000    0.175385  0.293498  0.312707  0.143477
# Population  0.007662  0.175385    1.000000  0.015108  0.021436 -0.050447
# Rate        0.007583  0.293498    0.015108  1.000000  0.993318  0.532902
# CI.lower    0.007635  0.312707    0.021436  0.993318  1.000000  0.519266
# CI.upper    0.009070  0.143477   -0.050447  0.532902  0.519266  1.000000

# %% [markdown]
# # Section 4: Visualizations
#
# ### This is also part of EDA! The whole process is rather cyclical. For this part, make 3 visualizations and describe what you see.
#
# ### Then, make 2 out of 3 these visualizations.
# ### 1. Heat Map
# ### 2. KDE Plot
# ### 3. Box Plot
#
# ### So in total, you should have made 5 visualizations.

# %%
#Visualization 1
# infection rates by year over all diseases

yearly_rates = df.groupby("Year").mean("Rate")
plt.plot(yearly_rates["Rate"])

#Your observations
# Infection rates peaked around 2005, 2010, and started to rise again in 2014 
# showing that infection rates peak around every 5 years

# %%
#Visualization 2
# Infection rates over the years separated by gender
female = df[df["Sex"] == "Female"].groupby("Year").mean("Rate")
male = df[df["Sex"] == "Male"].groupby("Year").mean("Rate")

fig, ax = plt.subplots()
ax.plot(female["Rate"], label = "Female")
ax.plot(male["Rate"], label = "Male")
ax.legend()

#Your observations
# Females on average had way higher infection rates than Males

# %%
#Visualization 3
# heat map correlation chart
corr = df.corr()
corr.style.background_gradient(cmap ='coolwarm')

#Your observations
# Out:
# <style type="text/css">
# #T_a665f_row0_col0, #T_a665f_row1_col1, #T_a665f_row2_col2, #T_a665f_row3_col3, #T_a665f_row4_col4, #T_a665f_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a665f_row0_col1, #T_a665f_row0_col3, #T_a665f_row0_col4, #T_a665f_row1_col0, #T_a665f_row2_col5, #T_a665f_row5_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a665f_row0_col2, #T_a665f_row0_col5 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_a665f_row1_col2 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_a665f_row1_col3 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_a665f_row1_col4 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_a665f_row1_col5 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_a665f_row2_col0, #T_a665f_row2_col3, #T_a665f_row3_col0, #T_a665f_row4_col0, #T_a665f_row5_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_a665f_row2_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_a665f_row2_col4 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_a665f_row3_col1 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_a665f_row3_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_a665f_row3_col4, #T_a665f_row4_col3 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_a665f_row3_col5 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_a665f_row4_col1 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_a665f_row4_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_a665f_row4_col5 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_a665f_row5_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_a665f_row5_col3 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_a665f_row5_col4 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# </style>
# <table id="T_a665f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Year</th>
#       <th class="col_heading level0 col1" >Count</th>
#       <th class="col_heading level0 col2" >Population</th>
#       <th class="col_heading level0 col3" >Rate</th>
#       <th class="col_heading level0 col4" >CI.lower</th>
#       <th class="col_heading level0 col5" >CI.upper</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a665f_level0_row0" class="row_heading level0 row0" >Year</th>
#       <td id="T_a665f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a665f_row0_col1" class="data row0 col1" >0.002295</td>
#       <td id="T_a665f_row0_col2" class="data row0 col2" >0.007662</td>
#       <td id="T_a665f_row0_col3" class="data row0 col3" >0.007583</td>
#       <td id="T_a665f_row0_col4" class="data row0 col4" >0.007635</td>
#       <td id="T_a665f_row0_col5" class="data row0 col5" >0.009070</td>
#     </tr>
#     <tr>
#       <th id="T_a665f_level0_row1" class="row_heading level0 row1" >Count</th>
#       <td id="T_a665f_row1_col0" class="data row1 col0" >0.002295</td>
#       <td id="T_a665f_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a665f_row1_col2" class="data row1 col2" >0.175385</td>
#       <td id="T_a665f_row1_col3" class="data row1 col3" >0.293498</td>
#       <td id="T_a665f_row1_col4" class="data row1 col4" >0.312707</td>
#       <td id="T_a665f_row1_col5" class="data row1 col5" >0.143477</td>
#     </tr>
#     <tr>
#       <th id="T_a665f_level0_row2" class="row_heading level0 row2" >Population</th>
#       <td id="T_a665f_row2_col0" class="data row2 col0" >0.007662</td>
#       <td id="T_a665f_row2_col1" class="data row2 col1" >0.175385</td>
#       <td id="T_a665f_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_a665f_row2_col3" class="data row2 col3" >0.015108</td>
#       <td id="T_a665f_row2_col4" class="data row2 col4" >0.021436</td>
#       <td id="T_a665f_row2_col5" class="data row2 col5" >-0.050447</td>
#     </tr>
#     <tr>
#       <th id="T_a665f_level0_row3" class="row_heading level0 row3" >Rate</th>
#       <td id="T_a665f_row3_col0" class="data row3 col0" >0.007583</td>
#       <td id="T_a665f_row3_col1" class="data row3 col1" >0.293498</td>
#       <td id="T_a665f_row3_col2" class="data row3 col2" >0.015108</td>
#       <td id="T_a665f_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_a665f_row3_col4" class="data row3 col4" >0.993318</td>
#       <td id="T_a665f_row3_col5" class="data row3 col5" >0.532902</td>
#     </tr>
#     <tr>
#       <th id="T_a665f_level0_row4" class="row_heading level0 row4" >CI.lower</th>
#       <td id="T_a665f_row4_col0" class="data row4 col0" >0.007635</td>
#       <td id="T_a665f_row4_col1" class="data row4 col1" >0.312707</td>
#       <td id="T_a665f_row4_col2" class="data row4 col2" >0.021436</td>
#       <td id="T_a665f_row4_col3" class="data row4 col3" >0.993318</td>
#       <td id="T_a665f_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_a665f_row4_col5" class="data row4 col5" >0.519266</td>
#     </tr>
#     <tr>
#       <th id="T_a665f_level0_row5" class="row_heading level0 row5" >CI.upper</th>
#       <td id="T_a665f_row5_col0" class="data row5 col0" >0.009070</td>
#       <td id="T_a665f_row5_col1" class="data row5 col1" >0.143477</td>
#       <td id="T_a665f_row5_col2" class="data row5 col2" >-0.050447</td>
#       <td id="T_a665f_row5_col3" class="data row5 col3" >0.532902</td>
#       <td id="T_a665f_row5_col4" class="data row5 col4" >0.519266</td>
#       <td id="T_a665f_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Visualization 4
# density plot for Rate of infections

sns.kdeplot(df["Rate"])

#Your observations
# Out:
# <AxesSubplot:xlabel='Rate', ylabel='Density'>

# %%
#Visualization 5
# box plots for infection rates grouped by areas
rates = df[df["Sex"] == "Total"].groupby("Disease").mean()[["Rate"]]

#ax = fig.add_axes([0, 0, 1, 1])
rates.boxplot()

#Your observations
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Which visualization is the best for your dataset and why?

# %%
#The best visualization for my data set is the line plot because it shows how the infection rates change over time 
# and the correlation matrix also is helpful in seeing how certain columns correspond with eachother

# %% [markdown]
# # Good job!
#
# ### As a quick wrap-up, think about how your biases might have affected your judgement and if there is anything you want to work on.
#
# ### As you can see, working with a dataset outside of class is much less structured. However, with practice, you will be become much sharper and efficient at wrangling data. Good luck with the next project!

# %%
# I think some biases that are apparent in this dataset may lie in how the data was collected, 
# but what I can do is to be transparent whenever working or manipulating data.

# %% [markdown]
# ### Fantastic job ~ Remember to push all your changes your GitHub repository and submit on Gradescope.
# ### Thank you for your time :)
# ### That's all for this homework!
